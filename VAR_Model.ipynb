# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.statespace.varmax import VARMAX
from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import grangercausalitytests, adfuller
# from tqdm import tqdm_notebook
from itertools import product

import matplotlib.pyplot as plt
import statsmodels.api as sm
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # VECTOR AUTO REGRESSION EQUATION:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
filepath = r"C:\Users\Admin\Downloads\Sales_Month.xlsx"
macro_data = pd.read_excel(filepath,parse_dates=['Month'],index_col='Month')
print(macro_data.shape)  # (123, 8)
macro_data.head()
# Out:
# (36, 4)
#             Company_Quantity  Company_Sales  Competitor_Quantity  \
# Month
# 2021-01-01            281.10      26.852712              1704955
# 2021-02-01            117.30      14.840290               710321
# 2021-03-01            336.60      26.309198              2448896
# 2021-04-01            152.53       8.797044              2866085
# 2021-05-01            264.16      13.172990              4962707
#
#             Competitor_Sales
# Month
# 2021-01-01         1050416.0
# 2021-02-01          580518.0
# 2021-03-01         1029155.0
# 2021-04-01         1829839.0
# 2021-05-01         2740062.0

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, dpi=120, figsize=(10,6))
for i, ax in enumerate(axes.flatten()):
    data = macro_data[macro_data.columns[i]]
    ax.plot(data, color='red', linewidth=1)
    # Decorations
    ax.set_title(macro_data.columns[i])
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout();

# %%
ad_fuller_result_1 = adfuller(macro_data['Competitor_Quantity'].diff()[1:])

print('Compe_Quantity')
print(f'ADF Statistic: {ad_fuller_result_1[0]}')
print(f'p-value: {ad_fuller_result_1[1]}')

print('\n---------------------\n')

ad_fuller_result_2 = adfuller(macro_data['Competitor_Sales'].diff()[1:])

print('Compe_Sales')
print(f'ADF Statistic: {ad_fuller_result_2[0]}')
print(f'p-value: {ad_fuller_result_2[1]}')

print('\n---------------------\n')

ad_fuller_result_3 = adfuller(macro_data['Company_Quantity'].diff()[1:])

print('Quantity')
print(f'ADF Statistic: {ad_fuller_result_3[0]}')
print(f'p-value: {ad_fuller_result_3[1]}')

print('\n---------------------\n')

ad_fuller_result_4 = adfuller(macro_data['Company_Sales'].diff()[1:])

print('Sales')
print(f'ADF Statistic: {ad_fuller_result_4[0]}')
print(f'p-value: {ad_fuller_result_4[1]}')
# Out:
# Compe_Quantity
# ADF Statistic: -5.7723864456207234
# p-value: 5.355000561717881e-07
#
# ---------------------
#
# Compe_Sales
# ADF Statistic: -5.183768871825836
# p-value: 9.488304510023994e-06
#
# ---------------------
#
# Quantity
# ADF Statistic: -5.5395061631634945
# p-value: 1.7143662242777151e-06
#
# ---------------------
#
# Sales
# ADF Statistic: -3.3202403509666674
# p-value: 0.013997619335187136

# %%
print('Company_Sales causes Company_Quantity?\n')
print('------------------')
granger_1 = grangercausalitytests(macro_data[['Company_Quantity', 'Company_Sales']], 8)

print('\nCompany_Quantity causes Company_Sales?\n')
print('------------------')
granger_2 = grangercausalitytests(macro_data[['Company_Sales', 'Company_Quantity']], 8)

print('Competitor_Sales causes Competitor_Quantity?\n')
print('------------------')
granger_3 = grangercausalitytests(macro_data[['Competitor_Quantity', 'Competitor_Sales']], 8)

print('\nCompetitor_Quantity causes Competitor_Sales?\n')
print('------------------')
granger_4 = grangercausalitytests(macro_data[['Competitor_Sales', 'Competitor_Quantity']], 8)
# Out:
# Company_Sales causes Company_Quantity?
#
# ------------------
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=4.2927  , p=0.0464  , df_denom=32, df_num=1
# ssr based chi2 test:   chi2=4.6952  , p=0.0302  , df=1
# likelihood ratio test: chi2=4.4058  , p=0.0358  , df=1
# parameter F test:         F=4.2927  , p=0.0464  , df_denom=32, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.5829  , p=0.0928  , df_denom=29, df_num=2
# ssr based chi2 test:   chi2=6.0566  , p=0.0484  , df=2
# likelihood ratio test: chi2=5.5737  , p=0.0616  , df=2
# parameter F test:         F=2.5829  , p=0.0928  , df_denom=29, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.0245  , p=0.1351  , df_denom=26, df_num=3
# ssr based chi2 test:   chi2=7.7087  , p=0.0524  , df=3
# likelihood ratio test: chi2=6.9278  , p=0.0742  , df=3
# parameter F test:         F=2.0245  , p=0.1351  , df_denom=26, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.3851  , p=0.2701  , df_denom=23, df_num=4
# ssr based chi2 test:   chi2=7.7085  , p=0.1029  , df=4
# likelihood ratio test: chi2=6.9066  , p=0.1409  , df=4
# parameter F test:         F=1.3851  , p=0.2701  , df_denom=23, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.8532  , p=0.5288  , df_denom=20, df_num=5
# ssr based chi2 test:   chi2=6.6121  , p=0.2511  , df=5
# likelihood ratio test: chi2=5.9935  , p=0.3068  , df=5
# parameter F test:         F=0.8532  , p=0.5288  , df_denom=20, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.8423  , p=0.5547  , df_denom=17, df_num=6
# ssr based chi2 test:   chi2=8.9186  , p=0.1782  , df=6
# likelihood ratio test: chi2=7.8082  , p=0.2525  , df=6
# parameter F test:         F=0.8423  , p=0.5547  , df_denom=17, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.6033  , p=0.7440  , df_denom=14, df_num=7
# ssr based chi2 test:   chi2=8.7480  , p=0.2713  , df=7
# likelihood ratio test: chi2=7.6455  , p=0.3649  , df=7
# parameter F test:         F=0.6033  , p=0.7440  , df_denom=14, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.5911  , p=0.7672  , df_denom=11, df_num=8
# ssr based chi2 test:   chi2=12.0366 , p=0.1496  , df=8
# likelihood ratio test: chi2=10.0125 , p=0.2641  , df=8
# parameter F test:         F=0.5911  , p=0.7672  , df_denom=11, df_num=8
#
# Company_Quantity causes Company_Sales?
#
# ------------------
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.9757  , p=0.3307  , df_denom=32, df_num=1
# ssr based chi2 test:   chi2=1.0672  , p=0.3016  , df=1
# likelihood ratio test: chi2=1.0512  , p=0.3052  , df=1
# parameter F test:         F=0.9757  , p=0.3307  , df_denom=32, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.5370  , p=0.5902  , df_denom=29, df_num=2
# ssr based chi2 test:   chi2=1.2592  , p=0.5328  , df=2
# likelihood ratio test: chi2=1.2364  , p=0.5389  , df=2
# parameter F test:         F=0.5370  , p=0.5902  , df_denom=29, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.4027  , p=0.7523  , df_denom=26, df_num=3
# ssr based chi2 test:   chi2=1.5333  , p=0.6746  , df=3
# likelihood ratio test: chi2=1.4988  , p=0.6826  , df=3
# parameter F test:         F=0.4027  , p=0.7523  , df_denom=26, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.8051  , p=0.5345  , df_denom=23, df_num=4
# ssr based chi2 test:   chi2=4.4807  , p=0.3448  , df=4
# likelihood ratio test: chi2=4.1936  , p=0.3804  , df=4
# parameter F test:         F=0.8051  , p=0.5345  , df_denom=23, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.9640  , p=0.4630  , df_denom=20, df_num=5
# ssr based chi2 test:   chi2=7.4707  , p=0.1879  , df=5
# likelihood ratio test: chi2=6.6932  , p=0.2445  , df=5
# parameter F test:         F=0.9640  , p=0.4630  , df_denom=20, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.7757  , p=0.1642  , df_denom=17, df_num=6
# ssr based chi2 test:   chi2=18.8013 , p=0.0045  , df=6
# likelihood ratio test: chi2=14.5968 , p=0.0236  , df=6
# parameter F test:         F=1.7757  , p=0.1642  , df_denom=17, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.4013  , p=0.2794  , df_denom=14, df_num=7
# ssr based chi2 test:   chi2=20.3188 , p=0.0049  , df=7
# likelihood ratio test: chi2=15.3993 , p=0.0312  , df=7
# parameter F test:         F=1.4013  , p=0.2794  , df_denom=14, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.0357  , p=0.4653  , df_denom=11, df_num=8
# ssr based chi2 test:   chi2=21.0908 , p=0.0069  , df=8
# likelihood ratio test: chi2=15.7211 , p=0.0466  , df=8
# parameter F test:         F=1.0357  , p=0.4653  , df_denom=11, df_num=8
# Competitor_Sales causes Competitor_Quantity?
#
# ------------------
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2036  , p=0.6549  , df_denom=32, df_num=1
# ssr based chi2 test:   chi2=0.2227  , p=0.6370  , df=1
# likelihood ratio test: chi2=0.2220  , p=0.6375  , df=1
# parameter F test:         F=0.2036  , p=0.6549  , df_denom=32, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.1015  , p=0.9038  , df_denom=29, df_num=2
# ssr based chi2 test:   chi2=0.2379  , p=0.8879  , df=2
# likelihood ratio test: chi2=0.2371  , p=0.8882  , df=2
# parameter F test:         F=0.1015  , p=0.9038  , df_denom=29, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.0690  , p=0.9760  , df_denom=26, df_num=3
# ssr based chi2 test:   chi2=0.2626  , p=0.9669  , df=3
# likelihood ratio test: chi2=0.2616  , p=0.9671  , df=3
# parameter F test:         F=0.0690  , p=0.9760  , df_denom=26, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.1037  , p=0.9801  , df_denom=23, df_num=4
# ssr based chi2 test:   chi2=0.5774  , p=0.9655  , df=4
# likelihood ratio test: chi2=0.5722  , p=0.9661  , df=4
# parameter F test:         F=0.1037  , p=0.9801  , df_denom=23, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.2651  , p=0.3173  , df_denom=20, df_num=5
# ssr based chi2 test:   chi2=9.8046  , p=0.0810  , df=5
# likelihood ratio test: chi2=8.5191  , p=0.1299  , df=5
# parameter F test:         F=1.2651  , p=0.3173  , df_denom=20, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.9178  , p=0.5061  , df_denom=17, df_num=6
# ssr based chi2 test:   chi2=9.7176  , p=0.1371  , df=6
# likelihood ratio test: chi2=8.4179  , p=0.2091  , df=6
# parameter F test:         F=0.9178  , p=0.5061  , df_denom=17, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.5697  , p=0.7689  , df_denom=14, df_num=7
# ssr based chi2 test:   chi2=8.2607  , p=0.3102  , df=7
# likelihood ratio test: chi2=7.2687  , p=0.4015  , df=7
# parameter F test:         F=0.5697  , p=0.7689  , df_denom=14, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.4239  , p=0.8835  , df_denom=11, df_num=8
# ssr based chi2 test:   chi2=8.6313  , p=0.3743  , df=8
# likelihood ratio test: chi2=7.5235  , p=0.4813  , df=8
# parameter F test:         F=0.4239  , p=0.8835  , df_denom=11, df_num=8
#
# Competitor_Quantity causes Competitor_Sales?
#
# ------------------
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.1119  , p=0.7401  , df_denom=32, df_num=1
# ssr based chi2 test:   chi2=0.1224  , p=0.7264  , df=1
# likelihood ratio test: chi2=0.1222  , p=0.7266  , df=1
# parameter F test:         F=0.1119  , p=0.7401  , df_denom=32, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3660  , p=0.6967  , df_denom=29, df_num=2
# ssr based chi2 test:   chi2=0.8581  , p=0.6511  , df=2
# likelihood ratio test: chi2=0.8475  , p=0.6546  , df=2
# parameter F test:         F=0.3660  , p=0.6967  , df_denom=29, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.2657  , p=0.8495  , df_denom=26, df_num=3
# ssr based chi2 test:   chi2=1.0117  , p=0.7984  , df=3
# likelihood ratio test: chi2=0.9965  , p=0.8021  , df=3
# parameter F test:         F=0.2657  , p=0.8495  , df_denom=26, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.8941  , p=0.1457  , df_denom=23, df_num=4
# ssr based chi2 test:   chi2=10.5410 , p=0.0322  , df=4
# likelihood ratio test: chi2=9.1115  , p=0.0584  , df=4
# parameter F test:         F=1.8941  , p=0.1457  , df_denom=23, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.1113  , p=0.3857  , df_denom=20, df_num=5
# ssr based chi2 test:   chi2=8.6128  , p=0.1255  , df=5
# likelihood ratio test: chi2=7.6001  , p=0.1797  , df=5
# parameter F test:         F=1.1113  , p=0.3857  , df_denom=20, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.8127  , p=0.1563  , df_denom=17, df_num=6
# ssr based chi2 test:   chi2=19.1936 , p=0.0038  , df=6
# likelihood ratio test: chi2=14.8370 , p=0.0216  , df=6
# parameter F test:         F=1.8127  , p=0.1563  , df_denom=17, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.2485  , p=0.3416  , df_denom=14, df_num=7
# ssr based chi2 test:   chi2=18.1030 , p=0.0115  , df=7
# likelihood ratio test: chi2=14.0662 , p=0.0500  , df=7
# parameter F test:         F=1.2485  , p=0.3416  , df_denom=14, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.1766  , p=0.3909  , df_denom=11, df_num=8
# ssr based chi2 test:   chi2=23.9605 , p=0.0023  , df=8
# likelihood ratio test: chi2=17.3118 , p=0.0270  , df=8
# parameter F test:         F=1.1766  , p=0.3909  , df_denom=11, df_num=8

# %%
macro_data = macro_data[['Company_Quantity','Company_Sales']]
#macro1_data = macro_data[['Competitor_Quantity','Competitor_Sales']]
print(macro_data.shape)
# Out:
# (36, 2)

# %%
train_df=macro_data[:int(0.8*(len(macro_data)))]
test_df=macro_data[int(0.8*(len(macro_data))):]

# %%
print(test_df.shape)
# Out:
# (8, 2)

# %%
model = VAR(train_df.diff()[1:])

# %%
sorted_order=model.select_order(maxlags=8)
print(sorted_order.summary())
# Out:
#  VAR Order Selection (* highlights the minimums)
# =================================================
#       AIC         BIC         FPE         HQIC
# -------------------------------------------------
# 0       13.88       13.98  1.068e+06*       13.90
# 1       13.92       14.22   1.116e+06       13.97
# 2       14.02       14.52   1.256e+06       14.10
# 3       14.01       14.71   1.310e+06       14.13
# 4       14.19       15.09   1.718e+06       14.34
# 5       14.19       15.29   2.022e+06       14.38
# 6       14.41       15.70   3.336e+06       14.63
# 7       13.51       15.00   2.268e+06       13.76
# 8      11.89*      13.58*   1.319e+06      12.18*
# -------------------------------------------------

# %%
var_model = VARMAX(train_df, order=(8,0),enforce_stationarity= True)
fitted_model = var_model.fit(disp=False)
print(fitted_model.summary())
# Out:
#                                      Statespace Model Results
# =================================================================================================
# Dep. Variable:     ['Company_Quantity', 'Company_Sales']   No. Observations:                   28
# Model:                                            VAR(8)   Log Likelihood                -245.515
#                                              + intercept   AIC                            565.030
# Date:                                   Mon, 22 Jan 2024   BIC                            614.322
# Time:                                           15:59:08   HQIC                           580.099
# Sample:                                       01-01-2021
#                                             - 04-01-2023
# Covariance Type:                                     opg
# ===================================================================================
# Ljung-Box (L1) (Q):             0.01, 0.00   Jarque-Bera (JB):           1.51, 1.25
# Prob(Q):                        0.93, 0.95   Prob(JB):                   0.47, 0.53
# Heteroskedasticity (H):         1.28, 1.80   Skew:                       0.56, 0.51
# Prob(H) (two-sided):            0.72, 0.40   Kurtosis:                   2.77, 2.82
#                          Results for equation Company_Quantity
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# intercept             186.0363      0.134   1393.316      0.000     185.775     186.298
# L1.Company_Quantity     0.5143      1.953      0.263      0.792      -3.314       4.342
# L1.Company_Sales       -8.4666      3.367     -2.514      0.012     -15.066      -1.867
# L2.Company_Quantity     0.1160      1.987      0.058      0.953      -3.779       4.011
# L2.Company_Sales        4.2695     13.897      0.307      0.759     -22.968      31.507
# L3.Company_Quantity    -0.2132      1.049     -0.203      0.839      -2.270       1.844
# L3.Company_Sales        2.8884     10.383      0.278      0.781     -17.462      23.239
# L4.Company_Quantity     0.1636      1.321      0.124      0.901      -2.425       2.752
# L4.Company_Sales       -3.4768     21.910     -0.159      0.874     -46.420      39.466
# L5.Company_Quantity    -0.0134      1.208     -0.011      0.991      -2.380       2.353
# L5.Company_Sales        1.7951      5.537      0.324      0.746      -9.058      12.648
# L6.Company_Quantity    -0.1973      4.770     -0.041      0.967      -9.545       9.151
# L6.Company_Sales       -3.1487      6.752     -0.466      0.641     -16.383      10.086
# L7.Company_Quantity     0.5184      2.729      0.190      0.849      -4.829       5.866
# L7.Company_Sales       -6.6040     14.403     -0.459      0.647     -34.833      21.625
# L8.Company_Quantity     0.1360      2.063      0.066      0.947      -3.907       4.179
# L8.Company_Sales        2.5428     12.383      0.205      0.837     -21.727      26.813
#                            Results for equation Company_Sales
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# intercept              19.3026      3.906      4.942      0.000      11.647      26.959
# L1.Company_Quantity     0.0050      0.227      0.022      0.982      -0.440       0.450
# L1.Company_Sales        0.0813      0.796      0.102      0.919      -1.479       1.642
# L2.Company_Quantity    -0.0097      0.085     -0.114      0.909      -0.176       0.157
# L2.Company_Sales        0.0563      1.186      0.047      0.962      -2.268       2.381
# L3.Company_Quantity     0.0490      0.172      0.285      0.776      -0.288       0.386
# L3.Company_Sales       -0.3897      1.794     -0.217      0.828      -3.906       3.127
# L4.Company_Quantity    -0.0343      0.124     -0.276      0.783      -0.278       0.209
# L4.Company_Sales        0.5918      1.962      0.302      0.763      -3.254       4.438
# L5.Company_Quantity    -0.0028      0.107     -0.026      0.979      -0.212       0.206
# L5.Company_Sales       -0.5148      0.735     -0.701      0.484      -1.955       0.925
# L6.Company_Quantity     0.0273      0.437      0.062      0.950      -0.829       0.883
# L6.Company_Sales       -0.2372      1.912     -0.124      0.901      -3.984       3.510
# L7.Company_Quantity     0.0268      0.185      0.145      0.885      -0.336       0.389
# L7.Company_Sales       -0.0695      2.517     -0.028      0.978      -5.002       4.863
# L8.Company_Quantity    -0.0102      0.168     -0.061      0.951      -0.339       0.318
# L8.Company_Sales       -0.0488      2.394     -0.020      0.984      -4.741       4.644
#                                           Error covariance matrix
# ===========================================================================================================
#                                               coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# sqrt.var.Company_Quantity                 108.7429     22.529      4.827      0.000      64.587     152.898
# sqrt.cov.Company_Quantity.Company_Sales     6.9642      8.597      0.810      0.418      -9.886      23.814
# sqrt.var.Company_Sales                      4.2260      5.522      0.765      0.444      -6.596      15.048
# ===========================================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 6.66e+18. Standard errors may be unstable.

# %%
n_forecast = 8
predict = fitted_model.get_prediction(start=len(train_df),end=len(train_df) + n_forecast-1)

predictions=predict.predicted_mean

# %%
predictions.columns=['Company_Quantity_pred','Company_Sales_pred']
predictions

# predictions.columns=['Competitor_Quantity_pred','Competitor_Sales_pred']
# predictions
# Out:
#             Company_Quantity_pred  Company_Sales_pred
# 2023-05-01             241.301133           10.940306
# 2023-06-01             294.194771           18.557287
# 2023-07-01             212.716570           22.411331
# 2023-08-01             170.344800           16.348943
# 2023-09-01             100.269448           10.116547
# 2023-10-01              76.181365           12.804886
# 2023-11-01              88.639907           19.440452
# 2023-12-01             141.210492           21.698264

# %%
test_vs_pred=pd.concat([test_df,predictions],axis=1)

# %%
test_vs_pred.plot(figsize=(12,5))
# Out:
# <Axes: >

# %%
from sklearn.metrics import mean_squared_error
import math 
from statistics import mean

rmse_quantity=math.sqrt(mean_squared_error(predictions['Company_Quantity_pred'],test_df['Company_Quantity']))
print('Mean value of Company_Quantity is : {}. Root Mean Squared Error is :{}'.format(mean(test_df['Company_Quantity']),rmse_quantity))

rmse_sales=math.sqrt(mean_squared_error(predictions['Company_Sales_pred'],test_df['Company_Sales']))
print('Mean value of Company_Sales is : {}. Root Mean Squared Error is :{}'.format(mean(test_df['Company_Sales']),rmse_sales))

# # For Quantity
# rmse_quantity = math.sqrt(mean_squared_error(predictions['Competitor_Quantity_pred'], test_df['Competitor_Quantity']))
# print('Mean value of Competitor_Quantity is: {}. Root Mean Squared Error is: {}'.format(mean(test_df['Competitor_Quantity']), rmse_quantity))

# # For Sales
# rmse_sales = math.sqrt(mean_squared_error(predictions['Competitor_Sales_pred'], test_df['Competitor_Sales']))
# print('Mean value of Competitor_Sales is: {}. Root Mean Squared Error is: {}'.format(mean(test_df['Competitor_Sales']), rmse_sales))
# Out:
# Mean value of Company_Quantity is : 206.86875. Root Mean Squared Error is :161.44422461106728
# Mean value of Company_Sales is : 20.693888744321754. Root Mean Squared Error is :9.687463286093374
